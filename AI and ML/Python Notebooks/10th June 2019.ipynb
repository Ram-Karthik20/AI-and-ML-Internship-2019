# %% [markdown]
# # AI and ML Internship
# ### B.Ram Karthik
#
# ### Day No-  15
#
# ### Date- 10-6-2019

# %% [markdown]
# ### Day Objectives
# * SLR-Python(Continuation)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df1= pd.read_csv('DataFiles/wc-at.csv')
df1
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# 5     71.85   21.68
# 6     80.90   29.08
# 7     83.40   32.98
# 8     63.50   11.44
# 9     73.20   32.22
# 10    71.90   28.32
# 11    75.00   43.86
# 12    73.10   38.21
# 13    79.00   42.48
# 14    77.00   30.96
# 15    68.85   55.78
# 16    75.95   43.78
# 17    74.15   33.41
# 18    73.80   43.35
# 19    75.90   29.31
# 20    76.85   36.60
# 21    80.90   40.25
# 22    79.90   35.43
# 23    89.20   60.09
# 24    82.00   45.84
# 25    92.00   70.40
# 26    86.60   83.45
# 27    80.50   84.30
# 28    86.00   78.89
# 29    82.50   64.75
# ..      ...     ...
# 79   109.00  192.00
# 80   103.50  132.00
# 81   110.00  126.00
# 82   110.00  153.00
# 83   112.00  158.00
# 84   108.50  183.00
# 85   104.00  184.00
# 86   111.00  121.00
# 87   108.50  159.00
# 88   121.00  245.00
# 89   109.00  137.00
# 90    97.50  165.00
# 91   105.50  152.00
# ...

# %%
log_m1 = smf.ols("AT ~ np.log(Waist)", data=df1).fit()
log_m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     AT   R-squared:                       0.675
# Model:                            OLS   Adj. R-squared:                  0.672
# Method:                 Least Squares   F-statistic:                     222.6
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           6.80e-28
# Time:                        14:24:00   Log-Likelihood:                -534.11
# No. Observations:                 109   AIC:                             1072.
# Df Residuals:                     107   BIC:                             1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
log_m2 = smf.ols("np.log(AT) ~ Waist", data=df1).fit()
log_m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             np.log(AT)   R-squared:                       0.707
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     258.3
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           2.68e-30
# Time:                        14:24:35   Log-Likelihood:                -40.123
# No. Observations:                 109   AIC:                             84.25
# Df Residuals:                     107   BIC:                             89.63
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7410      0.233      3.185      0.002       0.280       1.202
# ...

# %%
log_m3 = smf.ols("np.sqrt(AT) ~ np.sqrt(Waist)", data=df1).fit()
log_m3.summary()3
.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            np.sqrt(AT)   R-squared:                       0.719
# Model:                            OLS   Adj. R-squared:                  0.716
# Method:                 Least Squares   F-statistic:                     273.2
# Date:                Mon, 10 Jun 2019   Prob (F-statistic):           3.16e-31
# Time:                        14:24:59   Log-Likelihood:                -201.20
# No. Observations:                 109   AIC:                             406.4
# Df Residuals:                     107   BIC:                             411.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...
